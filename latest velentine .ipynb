# %%
import requests
import re

r = requests.get("https://www.goodreads.com/quotes/tag/valentine-s-day?page=1").text
ar = re.findall(r'<div class="quoteText">(.*?)<br>',r,re.S)
for i in ar:
    ans = i
# Out:
#       &ldquo;in a world<br />full of<br />temporary things<br /><br />you are<br />a perpetual <br />feeling.&rdquo;
#
#
#       &ldquo;If my Valentine you won't be,<br />I'll hang myself on your Christmas tree.&rdquo;
#
#
#       &ldquo;What a lover’s heart knows let no man’s brain dispute.&rdquo;
#
#
#       &ldquo;This fire that we call Loving is too strong for human minds. But just right for human souls.&rdquo;
#
#
#       &ldquo;Un-winged and naked, sorrow surrenders its crown to a throne called grace.&rdquo;
#
#
#       &ldquo;Most people are slow to champion love because they fear the transformation it brings into their lives. And make no mistake about it: love does take over and transform the schemes and operations of our egos in a very mighty way.&rdquo;
#
#
# ...
