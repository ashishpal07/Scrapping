# %%
# import requests
# from bs4 import BeautifulSoup

# r = requests.get('http://m.wishafriend.com/valentinesday/valentine-poems-for-him.php?pagenum=1')
# soup = BeautifulSoup(r.text, "html.parser")
# for link in soup.find_all('div',{'class':'message'}):
#     data = link.text
#     print(data)

import requests
from bs4 import BeautifulSoup

i =1
while(i<=3):
    r = requests.get('http://m.wishafriend.com/valentinesday/valentine-poems-for-him.php?pagenum={0}'.format(i))
    soup = BeautifulSoup(r.text, "html.parser")
    for link in soup.find_all('div',{'class':'message'}):
        data = link.text
        print(data)
        print()
    i +=1
# Out:
# When I hold you
# When I hold your hand tight,
# When I get mesmerized in your arms,
# It makes me so calm,
# That I forget all my fright,
# On this special day,
# Let me wish you today,
# A very happy Valentine's Day!
#
# Your love so true
# Your love has given me a solace in life,
# Your love has helped me to suffice,
# There is no special time to love you my dear,
# But, on this day I want to spread the cheer,
# That I love you so much,
# My love for you is such,
# Wishing you a very happy Valentine's Day!
#
# How will I express
# How will I express my love for you?
# On this very special day,
# I love you my dear and will love you,
# And I just have a word to say,
# That you are my life now,
# I don't know when this happened and how,
# But, I truly love you,
# Happy Valentine's Day!
#
# I love you more
# I love you more than me,
# There is no one beyond you I can see,
# Do you know how much I love you?
# Do you even have a clue?
# That without you I won't be able to do,
# ...
