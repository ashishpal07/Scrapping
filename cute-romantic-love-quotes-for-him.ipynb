# %%
import urllib.request
import re

url = "https://www.luvze.com/cute-romantic-love-quotes-for-him/"
r = requests.get(url).text

r = re.search("<h2>(.*?)I love you. I am at rest with you. I have come home. &#8211; Dorothy L. Sayers",r,re.S).group(1)

#for i in r:
    #q = re.search("[\"](font-weight)[\:]\s+(400)[\;][\"](>)\d+\.(.*?)(<)",r).group(4)
    #q = re.search('<span style="font-weight: 400;">\d+\.(.*?)<',i).group(1)

quote = re.findall('<span style="font-weight: 400;">\d+\.(.*?)<',r,re.S)
#quote = list(map(lambda Str:Str.decode(encoding='UTF-8',errors='strict'),quote))
print(quote)
# Out:
# [' I hope you know that every time I tell you to get home safe, stay warm, have a good day, or sleep well &#8211; what I am really saying is I love you. I love you so damn much that it is starting to steal other words’ meanings.', ' I saw that you were perfect, and so I loved you. Then I saw that you were not perfect and I loved you even more. &#8211; Angelita Lim', ' You are my best friend, my human diary and my other half. You mean the world to me and I love you.', ' If I know what love is, it is because of you. &#8211; Herman Hesse', ' I realized I was thinking of you, and I began to wonder how long you’d been on my mind. Then it occurred to me: Since I met you, you’ve never left.', ' You don’t love someone for their looks, or their clothes, or for their fancy car, but because they sing a song only you can hear. &#8211; Oscar Wilde', ' Wife: I love you. Husband: I love you too. Wife: Prove it, scream it to the world. Husband whispers in ear &#8216;I love you.&#8217; Wife: Why&#821
# ...

# %%
Str = "and I loved you even more. &#8211; Angelita Lim  Hipâ€™s"

Str.encode("windows-1252").decode("utf-8")


byte_string = b"&#8211;"

decoded_string = byte_string.decode("utf8")

print(decoded_string)
# Out:
# &#8211;
